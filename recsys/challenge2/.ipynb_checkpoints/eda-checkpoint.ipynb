# %%
# !pip install matplotlib

# %%
import pandas as pd 
import csv


ratings = pd.read_json("ratings.jsonl", lines=True)
targets = pd.read_csv("targets.csv")
content = pd.read_json("content.jsonl", lines=True)

drop_cols = ["totalSeasons", "Season", "Episode", "seriesID"]
content = content.drop(drop_cols, axis=1)
content = content.replace("N/A", 0)

# %%
content.imdbRating = content.imdbRating.astype(float)
# content.imdbVotes = content.imdbVotes.to_numeric()
content.imdbVotes= content.imdbVotes.str.replace(',', '').astype(float)

# %%
content.head()
# Out:
#        ItemId                                          Title  Year      Rated  \
# 0  c9f0f895fb         Edison Kinetoscopic Record of a Sneeze  1894          0
# 1  d3d9446802                            Leaving the Factory  1895  Not Rated
# 2  c20ad4d76f                         The Arrival of a Train  1896  Not Rated
# 3  8e296a067a  The Oxford and Cambridge University Boat Race  1895          0
# 4  54229abfcf                         The House of the Devil  1896  Not Rated
#
#       Released Runtime               Genre                        Director  \
# 0  09 Jan 1894   1 min  Documentary, Short            William K.L. Dickson
# 1  22 Mar 1895   1 min  Documentary, Short                   Louis Lumière
# 2  25 Jan 1896   1 min  Documentary, Short  Auguste Lumière, Louis Lumière
# 3            0       0  Short, News, Sport                      Birt Acres
# 4  24 Dec 1896   3 min       Short, Horror                  Georges Méliès
#
#            Writer                                             Actors  ...  \
# 0               0                                           Fred Ott  ...
# 1               0                                                  0  ...
# 2               0  Madeleine Koehler, Marcel Koehler, Mrs. August...  ...
# 3               0                                                  0  ...
# 4  Georges Méliès  Jehanne d'Alcy, Jules-Eugène Legris, Georges M...  ...
#
#                                              Ratings Metascore imdbRating  \
# 0  [{'Source': 'Internet Movie Database', 'Value'...         0        5.5
# 1  [{'Source': 'Internet Movie Database', 'Value'...         0        6.9
# 2  [{'Source': 'Internet Movie Database', 'Value'...         0        7.5
# 3  [{'Source': 'Internet Movie Database', 'Value'...         0        4.2
# 4  [{'Source': 'Internet Movie Database', 'Value'...         0        6.7
#
#   imdbVotes   Type DVD BoxOffice Production Website Response
# 0     1,980  movie   0         0          0       0     True
# 1     6,633  movie   0         0          0       0     True
# 2    11,407  movie   0         0          0       0     True
# 3        39  movie   0         0          0       0     True
# 4     3,268  movie   0         0          0       0     True
#
# [5 rows x 25 columns]

# %%
ratings.head()
# Out:
#        UserId      ItemId           Timestamp  Rating
# 0  c4ca4238a0  91766eac45 2013-10-05 22:00:50       8
# 1  c81e728d9d  5c739554f7 2013-08-17 16:26:38       9
# 2  c81e728d9d  48f6d7ce7c 2013-08-17 13:28:27       8
# 3  c81e728d9d  e9318d627a 2013-06-15 15:38:09       1
# 4  a87ff679a2  17e6357973 2014-01-31 23:27:59       8

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 659720 entries, 0 to 659719
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   UserId     659720 non-null  object
#  1   ItemId     659720 non-null  object
#  2   Timestamp  659720 non-null  datetime64[ns]
#  3   Rating     659720 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 20.1+ MB

# %%
ratings.Rating.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
content.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38012 entries, 0 to 38011
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ItemId      38012 non-null  object
#  1   Title       38012 non-null  object
#  2   Year        38012 non-null  object
#  3   Rated       38012 non-null  object
#  4   Released    38012 non-null  object
#  5   Runtime     38012 non-null  object
#  6   Genre       38012 non-null  object
#  7   Director    38012 non-null  object
#  8   Writer      38012 non-null  object
#  9   Actors      38012 non-null  object
#  10  Plot        38012 non-null  object
#  11  Language    38012 non-null  object
#  12  Country     38012 non-null  object
#  13  Awards      38012 non-null  object
#  14  Poster      38012 non-null  object
#  15  Ratings     38012 non-null  object
#  16  Metascore   38012 non-null  object
#  17  imdbRating  38012 non-null  object
#  18  imdbVotes   38012 non-null  object
#  19  Type        38012 non-null  object
#  20  DVD         37988 non-null  object
#  21  BoxOffice   37988 non-null  object
#  22  Production  37988 non-null  object
#  23  Website     37988 non-null  object
#  24  Response    38012 non-null  object
# dtypes: object(25)
# memory usage: 7.3+ MB

# %%
content.Director.unique()
# Out:
# array(['William K.L. Dickson', 'Louis Lumière',
#        'Auguste Lumière, Louis Lumière', ..., 'Florian Gottschick',
#        'Rishab Seth', 'Anawat Phromchae, Aroonakorn Pick'], dtype=object)

# %%
content.Genre.unique()
# Out:
# array(['Documentary, Short', 'Short, News, Sport', 'Short, Horror', ...,
#        'Mystery, Romance', 'Animation, Crime, Mystery',
#        'Short, Comedy, Game-Show'], dtype=object)

# %%
content.imdbVotes.unique().shape
# Out:
# (16343,)

# %%
users = targets.UserId.unique()

# %%
with open("output.csv", "w", newline='') as f:
    writer = csv.writer(f)
    writer.writerows([["UserId", "ItemId"]])

    result = []
    print(len(users))
    # for user in users[:5]:
    for user in users:
        items = targets.loc[targets.UserId == user].ItemId.to_numpy()
        movies = content.loc[content.ItemId.isin(items)]
        rank = movies.sort_values(by="imdbVotes", ascending=False).ItemId.to_numpy()
        
        writer.writerows(list(zip([user] * 100, rank)))
# Out:
# 6162

# %%
# movies.imdbRating.dtypes

# %%
movies.sort_values(by="imdbRating", ascending=False)
# Out:
#            ItemId                                      Title  Year      Rated  \
# 33683  e27e8b9547                  Ayla: The Daughter of War  2017          0
# 7465   4cde7bfdc2                                  Gitanjali  1989          0
# 34081  63f5c0e0cc                         The Wild Pear Tree  2018          0
# 31410  1e5bdbcb76  Three Billboards Outside Ebbing, Missouri  2017          R
# 24526  515d68e1ca                                 Special 26  2013  Not Rated
# ...           ...                                        ...   ...        ...
# 13034  defd71784e    Dumb and Dumberer: When Harry Met Lloyd  2003      PG-13
# 33628  9148404da2                        Sen Sag Ben Selamet  2016          0
# 34562  751244e2ae                                  Dabangg 3  2019  Not Rated
# 20470  8f49ce0461               Jurassic Predator: Xtinction  2014      TV-14
# 24550  b3560a34eb                   Priklyucheniye ne udalos  1974          0
#
#           Released  Runtime                      Genre  \
# 33683  27 Oct 2017  125 min  Biography, Drama, History
# 7465   19 May 1989  150 min             Drama, Romance
# 34081  30 Jan 2019  188 min                      Drama
# 31410  01 Dec 2017  115 min       Comedy, Crime, Drama
# 24526  08 Feb 2013  144 min     Crime, Drama, Thriller
# ...            ...      ...                        ...
# 13034  13 Jun 2003   85 min                     Comedy
# 33628  16 Dec 2016   98 min                     Comedy
# 34562  20 Dec 2019  160 min      Action, Comedy, Crime
# 20470  13 Nov 2018   90 min     Action, Horror, Sci-Fi
# 24550            0        0                     Family
#
#                           Director  \
# 33683  Can Ulkay, Halenur Uzunoglu
# 7465                   Mani Ratnam
# 34081            Nuri Bilge Ceylan
# 31410              Martin McDonagh
# 24526                Neeraj Pandey
# ...                            ...
# 13034                  Troy Miller
# 33628                  Ersoy Güler
# 34562                  Prabhu Deva
# 20470                 Amir Valinia
# 24550              Vagram Kevorkov
#
#                                                   Writer  \
# 33683                                       Yigit Güralp
# 7465                                Rajasri, Mani Ratnam
# 34081          Akin Aksu, Ebru Ceylan, Nuri Bilge Ceylan
# 31410                                    Martin McDonagh
# 24526                                      Neeraj Pandey
# ...                                                  ...
# 13034     Peter Farrelly, Bennett Yellin, Bobby Farrelly
# 33628                            Alper Erze, Ersoy Güler
# 34562            Salman Khan, Prabhu Deva, Alok Upadhyay
# 20470  George Michael Kostuch, Cameron Larson, Caleb ...
# 24550                                        Yuri Sotnik
#
#                                                   Actors  ...  \
# 33683     Çetin Tekindor, Ismail Hacioglu, Kyung-jin Lee  ...
# 7465     Nagarjuna Akkineni, Girija Shettar, Vijayakumar  ...
# 34081     Dogu Demirkol, Murat Cemcir, Bennu Yildirimlar  ...
# 31410   Frances McDormand, Woody Harrelson, Sam Rockwell  ...
# 24526          Akshay Kumar, Anupam Kher, Manoj Bajpayee  ...
# ...                                                  ...  ...
# 13034  Derek Richardson, Eric Christian Olsen, Eugene...  ...
# 33628           Ufuk Özkan, Burçin Bildik, Tuvana Türkay  ...
# 34562                Salman Khan, Sudeep, Sonakshi Sinha  ...
# 20470          Lochlyn Munro, Mark Sheppard, Elena Lyons  ...
# 24550  Aleksandr Bordukov, Nikolai Brilling, Sasha Ch...  ...
#
#                                                  Ratings Metascore imdbRating  \
# 33683  [{'Source': 'Internet Movie Database', 'Value'...         0        8.4
# 7465   [{'Source': 'Internet Movie Database', 'Value'...         0        8.3
# 34081  [{'Source': 'Internet Movie Database', 'Value'...        86        8.1
# 31410  [{'Source': 'Internet Movie Database', 'Value'...        88        8.1
# 24526  [{'Source': 'Internet Movie Database', 'Value'...         0        8.0
# ...                                                  ...       ...        ...
# 13034  [{'Source': 'Internet Movie Database', 'Value'...        19        3.4
# 33628  [{'Source': 'Internet Movie Database', 'Value'...         0        3.1
# 34562  [{'Source': 'Internet Movie Database', 'Value'...         0        3.0
# 20470  [{'Source': 'Internet Movie Database', 'Value'...         0        2.9
# 24550                                                 []         0        0.0
#
#       imdbVotes   Type          DVD    BoxOffice  Production Website Response
# 33683    37,652  movie            0            0           0       0     True
# 7465      2,454  movie            0            0           0       0     True
# 34081    23,313  movie  21 Aug 2019      $34,014           0       0     True
# 31410   475,339  movie  27 Feb 2018  $54,513,740           0       0     True
# 24526    54,419  movie  02 Mar 2017            0           0       0     True
# ...         ...    ...          ...          ...         ...     ...      ...
# 13034    39,003  movie  11 Nov 2003  $26,276,465           0       0     True
# 33628       346  movie            0            0           0       0     True
# 34562    18,010  movie  17 Feb 2020     $202,000           0       0     True
# 20470       894  movie            0            0           0       0     True
# 24550         0  movie            0            0           0       0     True
#
# [100 rows x 25 columns]

# %%
list(zip([12312] * 100, rank.to_numpy()))
# Out:
# [(12312, 'e27e8b9547'),
#  (12312, '4cde7bfdc2'),
#  (12312, '63f5c0e0cc'),
#  (12312, '1e5bdbcb76'),
#  (12312, '515d68e1ca'),
#  (12312, 'acbc7ae9f4'),
#  (12312, '777495036a'),
#  (12312, '1d8e71d3b4'),
#  (12312, '10dbc0cb47'),
#  (12312, '7ececef73a'),
#  (12312, '4b2de9def8'),
#  (12312, 'd1cafe5463'),
#  (12312, '9a130084b3'),
#  (12312, '9466eed1c5'),
#  (12312, '689aa5a01c'),
#  (12312, '528b0bef28'),
#  (12312, '44a83d0249'),
#  (12312, 'c7d57f1d63'),
#  (12312, '0a6fbee9b5'),
#  (12312, 'a3c335b8d5'),
#  (12312, '6fdd8f48f6'),
#  (12312, '28dd468edf'),
#  (12312, 'cd00685170'),
#  (12312, 'c38ca488ae'),
#  (12312, 'a2483d1dc1'),
#  (12312, 'a2a98bfca1'),
#  (12312, '9dea0c0668'),
#  (12312, 'ec0693b8b1'),
#  (12312, 'e880970dac'),
#  (12312, '3f49a3095c'),
#  (12312, '4e7e318c71'),
#  (12312, '25ff8f2084'),
#  (12312, 'f3360c27f7'),
#  (12312, '3448b0f6d6'),
#  (12312, 'b2f29522fa'),
#  (12312, 'c968583544'),
#  (12312, 'c91c68898d'),
#  (12312, 'df0a89ee5d'),
#  (12312, 'b96e695270'),
#  (12312, '3af385ca98'),
#  (12312, '4d66dccf02'),
#  (12312, '8b75b7b6a1'),
#  (12312, 'adbc75f065'),
#  (12312, '8f53e31924'),
#  (12312, 'd0c8aede21'),
#  (12312, '584381be0d'),
#  (12312, '048355f3b2'),
#  (12312, '8feb35769b'),
#  (12312, 'c4f8cc116a'),
#  (12312, '385e8453e9'),
#  (12312, '60c0e9c8ff'),
#  (12312, 'e1054bf2d7'),
#  (12312, '9fae2a98fe'),
#  (12312, '322351652a'),
#  (12312, 'e1302fe44a'),
#  (12312, 'a897ed1f5f'),
#  (12312, '8c0589f0ba'),
#  (12312, 'cf0f33003d'),
#  (12312, '39d1de6ab6'),
#  (12312, '6849aaba1d'),
#  (12312, '3510418ba0'),
#  (12312, 'bf8774e08d'),
#  (12312, '5f7618eae4'),
#  (12312, '129627f8ce'),
#  (12312, 'af5c63d9c1'),
#  (12312, 'aaff5b3c2a'),
#  (12312, 'bdee2ae161'),
#  (12312, 'f5f994eca0'),
#  (12312, 'b1a603616d'),
#  (12312, 'bd4a7bdeca'),
#  (12312, '525fc4c705'),
#  (12312, 'ed5609fd6e'),
#  (12312, '5d3d1a17bf'),
#  (12312, 'b5342a000b'),
#  (12312, 'd248f077d1'),
#  (12312, '9b5465a5c7'),
#  (12312, '75d64f1a45'),
#  (12312, '15764dacd6'),
#  (12312, '930f7352a3'),
#  (12312, '143dd9abaf'),
#  (12312, '7fbe4723f3'),
#  (12312, '9ef1302243'),
#  (12312, 'bb27d63935'),
#  (12312, '50dd27278a'),
#  (12312, '4feba131e1'),
#  (12312, 'fe717b41d0'),
#  (12312, '047dd3c542'),
#  (12312, '7439310841'),
#  (12312, '4d04118201'),
#  (12312, 'ee48cfc11e'),
#  (12312, '5d22b5752e'),
#  (12312, '31cc13bca1'),
#  (12312, 'bf093076c6'),
#  (12312, '1d01cd2d78'),
#  (12312, 'bf2c4601b1'),
#  (12312, 'defd71784e'),
#  (12312, '9148404da2'),
#  (12312, '751244e2ae'),
#  (12312, '8f49ce0461'),
#  (12312, 'b3560a34eb')]

# %%
movies.head()
# Out:
#           ItemId                 Title  Year      Rated     Released  Runtime  \
# 31    e1054bf2d7             The Cheat  1915  Not Rated  13 Dec 1915   59 min
# 68    0a6fbee9b5             Neighbors  1920          0  22 Dec 1920   18 min
# 497   c91c68898d  Crime and Punishment  1935  Not Rated  11 Jan 1936   88 min
# 1553  3f49a3095c            Rio Grande  1950     Passed  15 Nov 1950  105 min
# 1994  6849aaba1d              Escapade  1955          0  12 Oct 1956   87 min
#
#                        Genre                        Director  \
# 31            Drama, Romance                Cecil B. DeMille
# 68    Short, Comedy, Romance  Edward F. Cline, Buster Keaton
# 497             Crime, Drama             Josef von Sternberg
# 1553        Romance, Western                       John Ford
# 1994           Comedy, Drama                  Philip Leacock
#
#                                               Writer  \
# 31                Hector Turnbull, Jeanie Macpherson
# 68                    Buster Keaton, Edward F. Cline
# 497   Joseph Anthony, Fyodor Dostoevsky, S.K. Lauren
# 1553     James Kevin McGuinness, James Warner Bellah
# 1994          Roger MacDougall, Donald Ogden Stewart
#
#                                           Actors  ...  \
# 31       Fannie Ward, Sessue Hayakawa, Jack Dean  ...
# 68    Buster Keaton, Edward F. Cline, Jack Duffy  ...
# 497     Edward Arnold, Peter Lorre, Marian Marsh  ...
# 1553     John Wayne, Maureen O'Hara, Ben Johnson  ...
# 1994   John Mills, Yvonne Mitchell, Alastair Sim  ...
#
#                                                 Ratings Metascore imdbRating  \
# 31    [{'Source': 'Internet Movie Database', 'Value'...         0        6.6
# 68    [{'Source': 'Internet Movie Database', 'Value'...         0        7.6
# 497   [{'Source': 'Internet Movie Database', 'Value'...         0        7.0
# 1553  [{'Source': 'Internet Movie Database', 'Value'...         0        7.1
# 1994  [{'Source': 'Internet Movie Database', 'Value'...         0        6.4
#
#      imdbVotes   Type          DVD BoxOffice Production Website Response
# 31       2,524  movie  06 Mar 2001         0          0       0     True
# 68       4,041  movie            0         0          0       0     True
# 497      1,938  movie  06 Oct 2015         0          0       0     True
# 1553    15,594  movie  14 Jul 1998         0          0       0     True
# 1994       162  movie            0         0          0       0     True
#
# [5 rows x 25 columns]
